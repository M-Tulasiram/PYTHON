# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Tulasiram/python-code/blob/main/Exercise_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.indexing
#2.slicing
#3.concatenation
#4.repetation
#5.membership operators
#6.iteration

# %%
L1 = [11,55,'c',"ram"]
L2 = [22,66,'d',"adfg"]

print("Indexing")
print(L1[2])#indexing
print("Slicing")
print(L1[0:4])#slicing
print("concatenation")
print(L1+L2)#concatenation
print("repetation")
print(L1*3)#repetation
print("membership operator")
print(22 in L2)#membership operator
print(iteration)
for i in L2:
  print(i,end=" ")#iteration
# Out:
# Indexing
# c
# Slicing
# [11, 55, 'c', 'ram']
# concatenation
# [11, 55, 'c', 'ram', 22, 66, 'd', 'adfg']
# repetation
# [11, 55, 'c', 'ram', 11, 55, 'c', 'ram', 11, 55, 'c', 'ram']
# membership operator
# True
# 22 66 d adfg

# %%
L1 = [11,22,33,44,55,66]
L2 = [12,23,34,45,56,67]
print(sum(L1))
print(max(L1))
print(min(L1))
print(sum(L2))
print(max(L2))
print(min(L2))
# Out:
# 231
# 66
# 11
# 237
# 67
# 12
