# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Tulasiram/python-code/blob/main/EXERCISE7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TUPLE
t1 = (10,20,30)
t2 = (40,50,60)
t3 = (1,2,3,(4,5,6))
print(type(t1))
print(type(t2))
print(type(t3))
print(t1)
print(t2)
print(t1+t2)
print(t1*4)
print(len(t2))
for i in t1:
  print(i,end = " ")
print()
if 20 in t1 :
  print("YES")
else:
  print("NO")
print(t1[0:2])
print(t2[1:2:2])
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (10, 20, 30)
# (40, 50, 60)
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 10, 20, 30, 10, 20, 30, 10, 20, 30)
# 3
# 10 20 30
# YES
# (10, 20)
# (50,)

# %%
#tuple index
print(t1.count(20))
print(t2.index(60))
# Out:
# 1
# 2

# %%
#tuple functions
print(sum(t1))
print(max(t2))
print(min(t1))
# Out:
# 60
# 60
# 10

# %%
#tuple zip
print(tuple(zip(t1,t2,t3)))
print(list(zip(t1,t2,t3)))
# Out:
# ((10, 40, 1), (20, 50, 2), (30, 60, 3))
# [(10, 40, 1), (20, 50, 2), (30, 60, 3)]

# %%
t4 = tuple(map(int,input().split()))
print(t4)
# Out:
# 1 2 3
# (1, 2, 3)

# %%
#write  a program to create tuples(name,age,address,college) for atleast two
#members and concatenate the tuples and print the concatenated tuples
s1 =('ram',19,'ongole','vit')
s2 = ('nari',18,'parvathipuram','vit')
print(s1)
print(s2)
print(s1+s2)
# Out:
# ('ram', 19, 'ongole', 'vit')
# ('nari', 18, 'parvathipuram', 'vit')
# ('ram', 19, 'ongole', 'vit', 'nari', 18, 'parvathipuram', 'vit')

# %%
#write a program t ocount the number of vowels in a string (no control flow allowed)
s = str(input("Enter a string:"))
s1 = s.lower()
vowels_count = s1.count('a')+s1.count('e')+s1.count('i')+s1.count('o')+s1.count('u')
print(vowels_count)
# Out:
# Enter a string:ram
# 1

# %%
a = {1,2,3}
b = {2,3}
print(a|b)
print(a&b)
print(a-b)
print(a^b)
print(a.issuperset(b))
print(b.issubset(a))
print(a.isdisjoint(b))
b.add(9)
print(b)
a.update([7,8])
print(a)
a.remove(8)
print(a)
a.discard(7)
print(a)
c = a.copy()
print(c)
e.pop()
# Out:
# {1, 2, 3}
# {2, 3}
# {1}
# {1}
# True
# True
# False
# {9, 2, 3}
# {1, 2, 3, 7, 8}
# {1, 2, 3, 7}
# {1, 2, 3}
# {1, 2, 3}
